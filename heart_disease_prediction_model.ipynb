# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df['trestbps'].plot(kind='line', figsize=(8, 4), title='trestbps')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['age'].plot(kind='line', figsize=(8, 4), title='age')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['sex'].plot(kind='hist', bins=20, title='sex')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.shape
# Out:
# (303, 14)

# %%
print(df["ca"].value_counts())
sns.countplot(x='ca',data=df,palette='RdBu_r')
plt.show()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: ca, dtype: int64

# %%
x= df.groupby('thal')['target'].sum().index
y=df.groupby('thal')['target'].sum()
# to create bar plot with custom colors
colors = sns.color_palette("Set2", len(df['thal'].unique()))
plt.figure(figsize=(10, 6))
sns.barplot(x=x,y=y,data=df)
plt.title('Heart Disease by thal')
plt.ylabel('target')
plt.show()

# %%
x= df.groupby('oldpeak')['target'].sum().index
y=df.groupby('oldpeak')['target'].sum()
# to create bar plot with custom colors
colors = sns.color_palette("Set2", len(df['oldpeak'].unique()))
plt.figure(figsize=(10, 6))
sns.barplot(x=x,y=y,data=df)
plt.title('Heart Disease by oldpeak')
plt.ylabel('target')
plt.show()

# %%
print(df["thal"].value_counts())
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
print(df["slope"].value_counts())
print(df["restecg"].value_counts())
# Out:
# 2    142
# 1    140
# 0     21
# Name: slope, dtype: int64
# 1    152
# 0    147
# 2      4
# Name: restecg, dtype: int64

# %%
df["cp"].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
df["fbs"].value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
df["exang"].value_counts()
# Out:
# 0    204
# 1     99
# Name: exang, dtype: int64

# %%
df.describe(include='all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (302, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# # 1 = Defective Heart
# # 0 = Healthy Heart

# %%
sns.countplot(x='target',data=df,palette='RdBu_r')
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="RdYlGn")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
for i in df.columns:
    df.boxplot(column=i)
    plt.show()

# %%
arr=['trestbps', 'chol', 'fbs', 'thalach','oldpeak', 'ca', 'thal']
new_df=df.copy()
for col in arr:
    Q1 = new_df[col].quantile(0.25)
    Q3 = new_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    new_df[col] = np.where(
        new_df[col] > upper_bound,
        upper_bound,
        np.where(
            new_df[col] < lower_bound,
            lower_bound,
            new_df[col]
        )
    )
df = new_df

# %%
for i in df.columns:
    new_df.boxplot(column=i)
    plt.show()

# %%
X=new_df.drop("target",axis=1)
Y=new_df.target

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X= scaler.fit_transform(X)

# %%
print(X)
# Out:
# [[ 0.94979429  0.68265615  1.97647049 ... -2.27118179 -0.75736977
#   -2.19381164]
#  [-1.92854796  0.68265615  1.005911   ... -2.27118179 -0.75736977
#   -0.5291606 ]
#  [-1.48572607 -1.46486632  0.0353515  ...  0.97951442 -0.75736977
#   -0.5291606 ]
#  ...
#  [ 1.50332164  0.68265615 -0.93520799 ... -0.64583368  1.51850754
#    1.13549045]
#  [ 0.28556146  0.68265615 -0.93520799 ... -0.64583368  0.38056889
#    1.13549045]
#  [ 0.28556146 -1.46486632  0.0353515  ... -0.64583368  0.38056889
#   -0.5291606 ]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y ,test_size=0.3,random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
print(Y.shape, y_train.shape, y_test.shape)
# Out:
# (302, 13) (211, 13) (91, 13)
# (302,) (211,) (91,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_C = grid_search.best_params_['C']

print("Best value of C:", best_C)
# Out:
# Best value of C: 0.1

# %% [markdown]
# # LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
y_pred = model.predict(X_test)

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[34  8]
#  [ 6 43]]
# Accuracy: 0.8461538461538461
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        42
#            1       0.84      0.88      0.86        49
#
#     accuracy                           0.85        91
#    macro avg       0.85      0.84      0.84        91
# weighted avg       0.85      0.85      0.85        91

# %%
from sklearn.model_selection import cross_val_score

# Linear Regression Model
LR_cv = cross_val_score(model,X,Y,cv=5,scoring="accuracy")
LR_cv = LR_cv.mean()
print(f'Linear Regression Score: {LR_cv}')
# Out:
# Linear Regression Score: 0.8442622950819672

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(70.72222222222221, 0.5, 'Actual')

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve 
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, y_pred)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %%
input_data = (56,1,1,130,221,0,0,163,0,0,2,0,3)
input_data_as_numpy_array= np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [1]
# The Person has Heart Disease

# %%
input_data = (51,0,0,130,305,0,1,142,1,1.2,1,0,3)
input_data_as_numpy_array= np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [0]
# The Person does not have a Heart Disease

# %%
import joblib
joblib.dump(model, 'heart_disease_prediction_model.joblib')
# Out:
# ['heart_disease_prediction_model.joblib']
